# %% [markdown]
# <a href="https://colab.research.google.com/github/GiaHan2702/image_processing/blob/main/Lab3_ex1_histogramequal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
import math
from google.colab import drive
#drive.mount('/content/drive')
import os

# %%
# display ori image
image1 = cv2.imread('/content/drive/MyDrive/Colab Notebooks/Image Processing Files Data/lab3/brain.jpg',cv2.IMREAD_GRAYSCALE)
image2 = cv2.imread('/content/drive/MyDrive/Colab Notebooks/Image Processing Files Data/lab3/bay.jpg',cv2.IMREAD_GRAYSCALE)

# %%
cv2_imshow(image1)
cv2_imshow(image2)
# Out:
# <PIL.Image.Image image mode=L size=820x754>
# <PIL.Image.Image image mode=L size=1024x683>

# %% [markdown]
# # ex1: display original img (grayscale) and its histogram (bay.jpg braij.jpg)
# # a. perform histogram equalization to the original img
# #b. display equalized histogram img to its histogram

# %%
print('Size of Image Brain:')
x = np.size(image1)
print('Size of Image Bay:')
y = np.size(image2)

print(x)
print (y)
plt.hist(image1.ravel(), bins=256, range=(0.0, 1.0), fc='k', ec='k') #calculating histogram of brain
plt.hist(image2.ravel(), bins=256, range=(0.0, 1.0), fc='k', ec='k') #calculating histogram of bay

plt.subplot(221)
plt.imshow(image1, cmap = 'gray')
plt.title('Original Image Brain')
plt.subplot(222)
plt.hist(image1.ravel(),256,[0,256])
plt.title('Histogram of image brain')
plt.subplot(223)
plt.imshow(image2, cmap = 'gray')
plt.title('Original Image Bay')
plt.subplot(224)
plt.hist(image2.ravel(),256,[0,256])
plt.title('Histogram of image Bay')
plt.show()


# another way
#counts, index = plt.hist(image)
#counts, index = np.histogram(image)
#plt.bar(counts,index)
# Out:
# Size of Image Brain:
# Size of Image Bay:
# 618280
# 699392
# <ipython-input-46-6dcae84fe791>:11: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(221)

# %%
equal1 = cv2.equalizeHist(image1)
equal2 = cv2.equalizeHist(image2)
res1 = np.hstack((image1,equal1)) #stacking images side-by-side
cv2_imshow(res1)

#just grayscale image and output is our histogram equalized image.
# Out:
# <PIL.Image.Image image mode=L size=1640x754>

# %%
res2 = np.hstack((image2,equal2)) #stacking images side-by-side
cv2_imshow(res2)
# Out:
# <PIL.Image.Image image mode=L size=2048x683>

# %%
x1 = np.size(equal1)

print(x)
plt.hist(equal1.ravel(), bins=256, range=(0.0, 1.0), fc='k', ec='k') #calculating histogram


plt.subplot(121)
plt.imshow(equal1, cmap = 'gray')
plt.title('Equalize Image Brain')
plt.subplot(122)
plt.hist(equal1.ravel(),256,[0,256])
plt.title('Histogram of Equalize Image Brain')
plt.show()
# save img on drive
path1 = '/content/drive/MyDrive/Colab Notebooks/Image Processing Files Data/lab3'
plt.savefig(os.path.join(path1, 'equal1_his.png'), dpi = 600)
# Out:
# 618280
# <ipython-input-49-ca0bb7982318>:7: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(121)

# %%
x2 = np.size(equal2)

print(x)
plt.hist(equal2.ravel(), bins=256, range=(0.0, 1.0), fc='k', ec='k') #calculating histogram


plt.subplot(121)
plt.imshow(equal2, cmap = 'gray')
plt.title('Equalize Image Bay')
plt.subplot(122)
plt.hist(equal2.ravel(),256,[0,256])
plt.title('Histogram of Equalize Image Bay')
plt.show()
# Out:
# 618280
# <ipython-input-50-0e640d350448>:7: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(121)

# %% [markdown]
# # sua bai

# %%
# plot ori img
fig,(fig1,fig2) = plt.subplots(1,2,figsize = (20,5))
plt.subplot(121), plt.imshow(image2, cmap = 'gray')
plt.title('Ori img bay')

# calculate histogram cv2.calhist : receive 5 inputs: (img, channels, masks, hist size...)
# pyimagesearch.com
# grayscale channel = 0; mask:mat na can bang histogram: ko xai
hist = cv2.calcHist([image2],[0],None,[256],[0,256])

#display
fig2.bar(np.arange(256),hist.ravel()), fig2.grid(color = 'black', linestyle = '--')
fig2.set_xlim([0,255]), fig2.set_ylim(0, max(hist)*1.1)
fig2.set_xlabel('Intensity'), fig2.set_ylabel('# of pixel')
fig2.set_title('Histogram')

# save img on drive
path = '/content/drive/MyDrive/Colab Notebooks/Image Processing Files Data/lab3'
plt.savefig(os.path.join(path, 'ori_img2_his.png'), dpi = 600)

# %%
#perform histogram equalization to ori img

# %%
eqImg = cv2.equalizeHist(image2)
# plot ori img
fig,(fig3,fig4) = plt.subplots(1,2,figsize = (20,5))
plt.subplot(121), plt.imshow(eqImg, cmap = 'gray')
plt.title('Equal img bay')

# calculate histogram cv2.calhist : receive 5 inputs: (img, channels, masks, hist size...)
# pyimagesearch.com
# grayscale channel = 0; mask:mat na can bang histogram: ko xai
hist = cv2.calcHist([eqImg],[0],None,[256],[0,256])

#display
fig4.bar(np.arange(256),hist.ravel()), fig4.grid(color = 'black', linestyle = '--')
fig4.set_xlim([0,255]), fig4.set_ylim(0, max(hist)*1.1)
fig4.set_xlabel('Intensity'), fig4.set_ylabel('# of pixel')
fig4.set_title('Histogram')
# Out:
# Text(0.5, 1.0, 'Histogram')

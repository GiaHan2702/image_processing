# %% [markdown]
# <a href="https://colab.research.google.com/github/GiaHan2702/image_processing/blob/main/Lab1__IMG_Pro_Exercise_3_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lab1_ Exercise 3: Given a color image entitled ‘nature_wallpaper.jpg’.
# 1)	Display the original image
# 2)	Display three primary components of the image: Blue, Green, Red
# 3)	Merge three components in new order: Green, Blue, Red and display the merged image

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
import math

# %%
 # load test image
color_Img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/Image Processing Files Data/nature_wallpaper.jpg',cv2.IMREAD_COLOR)
# convert to float and normalize it
color_Img = color_Img.astype(np.float32)/255.0

# %%
# Extract 3 colors channel
red_channel = color_Img[:,:,2]
green_channel = color_Img[:,:,1]
blue_channel = color_Img[:,:,0]
# Create empty image with same shape as that of src image
red_img = np.zeros(color_Img.shape)
green_img = np.zeros(color_Img.shape)
blue_img = np.zeros(color_Img.shape)

# Assign the red channel of src to empty image
red_img[:,:,2] = red_channel
green_img[:,:,1] = green_channel
blue_img[:,:,0] = blue_channel

plt.subplot(1,3,1)
plt.imshow(red_img)
plt.subplot(1,3,2)
plt.imshow(green_img)
plt.subplot(1,3,3)
plt.imshow(blue_img)# Extract 3 colors channel
red_channel = color_Img[:,:,2]
green_channel = color_Img[:,:,1]
blue_channel = color_Img[:,:,0]
# Create empty image with same shape as that of src image
red_img = np.zeros(color_Img.shape)
green_img = np.zeros(color_Img.shape)
blue_img = np.zeros(color_Img.shape)

# Assign the red channel of src to empty image
red_img[:,:,2] = red_channel
green_img[:,:,1] = green_channel
blue_img[:,:,0] = blue_channel

plt.subplot(1,3,1)
plt.imshow(red_img)
plt.subplot(1,3,2)
plt.imshow(green_img)
plt.subplot(1,3,3)
plt.imshow(blue_img)

# %%
# read and display 3 primary components

#B,G,R = cv2.split(color_Img)
#cv2_imshow(cv2.merge([B,np.zeros_like(B),0]))
#cv2_imshow(cv2.merge([G,np.zeros_like(G),0]))
#cv2_imshow(cv2.merge([R,np.zeros_like(R),0]))

b,g,r = cv2.split(color)
zeros = np.zeros_like(b)
only_red = cv2.merge((zeros, zeros, r))

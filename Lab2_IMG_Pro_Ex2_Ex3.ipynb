# %% [markdown]
# <a href="https://colab.research.google.com/github/GiaHan2702/image_processing/blob/main/Lab2_IMG_Pro_Ex2_Ex3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
import math
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from skimage.util import random_noise

# %%
# display ori image
image = cv2.imread('/content/drive/MyDrive/Colab Notebooks/Image Processing Files Data/Lab2/quadnight.jfif',cv2.IMREAD_GRAYSCALE)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=L size=1024x768>

# %%
# Image subtraction

# load img


liveImg = cv2.imread('/content/drive/MyDrive/Colab Notebooks/Image Processing Files Data/Lab2/live.jpg',cv2.IMREAD_GRAYSCALE)/255
maskImg = cv2.imread('/content/drive/MyDrive/Colab Notebooks/Image Processing Files Data/Lab2/mask.jpg',cv2.IMREAD_GRAYSCALE)/255

plt.subplot(1,2,1)
plt.imshow(liveImg, cmap ='gray')
plt.subplot(1,2,2)
plt.imshow(maskImg, cmap ='gray')

# %%
#calculate the difference
diffImg = np.abs(liveImg - maskImg)
gamma = 0.5

diffImg_contrasted = np.power(diffImg,gamma)
plt.subplot(121)
plt.imshow(diffImg*255, cmap ='gray')
plt.title('Difference Image')
plt.subplot(122)
plt.imshow(diffImg_contrasted*255, cmap ='gray')
plt.title('Different Image contrasted')
# Out:
# Text(0.5, 1.0, 'Different Image contrasted')

# %%
# problem 3
# apply the same with picture: maskdiff
# Image subtraction

# load img

mask1Img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/Image Processing Files Data/Lab2/mask1.png',cv2.IMREAD_GRAYSCALE)/255
mask2Img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/Image Processing Files Data/Lab2/mask2.png',cv2.IMREAD_GRAYSCALE)/255

plt.subplot(1,2,1)
plt.imshow(mask1Img, cmap ='gray')
plt.title('mask1')
plt.subplot(1,2,2)
plt.imshow(mask2Img, cmap ='gray')
plt.title('mask2')
# Out:
# Text(0.5, 1.0, 'mask2')

# %%
#calculate the difference
diffImg = np.abs(mask1Img - mask2Img)
gamma = 0.3 # <<< lighter

diffImg_contrasted = np.power(diffImg,gamma)
plt.subplot(121)
plt.imshow(diffImg, cmap ='gray')
plt.title('Difference Image')
plt.subplot(122)
plt.imshow(diffImg_contrasted, cmap ='gray')
plt.title('Different Image contrasted')
plt.show()

# %%
# convert BGR to RGB
#cv2.cvtColor(mask1Img, cv2.COLOR_BGR2RGB)
#cv2_imshow(cv2.cvtColor(mask1Img, cv2.COLOR_BGR2RGB))
#cv2_imshow(cv2.cvtColor(mask2Img, cv2.COLOR_BGR2RGB))

#diff_img = np.absolute(mask1Img - mask2Img)

# plt.imshow(diff_img, cmap = 'gray')
